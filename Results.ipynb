# %%
import json
import matplotlib.pyplot as plt

# %%
buff = None
with open('models/model_100_100_final.json', 'r') as f:
    buff = f.read()
    
history = json.loads(buff)
history.keys()
# Out:
# dict_keys(['loss', 'class_out_loss', 'box_out_loss', 'class_out_accuracy', 'box_out_iou', 'lr'])

# %%
plt.plot(history['class_out_loss'])

# %%
plt.plot(history['class_out_accuracy'])

# %%
plt.plot(history['box_out_iou'])
